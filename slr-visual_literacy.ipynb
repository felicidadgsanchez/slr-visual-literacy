# %%
# -*- coding: utf-8 -*-
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 20)


import numpy as np

from scipy import stats

from bokeh.io import show, output_file
from bokeh.plotting import figure

 
# use creds to create a client to interact with the Google Drive API
scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name('client_secret.json', scope)
client = gspread.authorize(creds)

from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.transform import factor_cmap
from bokeh.palettes import Category20b
from bokeh.models import LabelSet
import math

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
# print("The following sheets are available")
# for sheet in client.openall():
#    print("{} - {}".format(sheet.title, sheet.id))

# %%
spreadsheet = client.open_by_key("170_PZ_BE6yzx00GEOHvqacHhfdb1PWlFpmy0BJ-FFzw")
sheetFinalResults = spreadsheet.get_worksheet(5)

# %%
#list_of_hashesA = sheetA1.get_all_records()
#print(list_of_hashes)

data = pd.DataFrame(sheetFinalResults.get_all_records())

print("Number of papers resulting the SLR: ", len(data))
# Out:
# Number of papers resulting the SLR:  39

# %%
display(data.head())
# Out:
#                                                 Authors  \
# 0  1                          Bel Martinez, Juan Carlos
# 1  2       Cheng, Chu-Yu; Ou, Yang-Kun; Kin, Ching-Lung
# 2  3               Oliveira, Alandeom W.; Cook, Kristin
# 3  4                                    Cappello, Marva
# 4  5  Gamez-Ceruelo, Virginia; Saez-Rosenkranz, Isidora
#
#                                   Concepto/Tendencia  \
# 0                          Educación/profes historia
# 1  Para alumnos del mundo del diseño. Revisión li...
# 2  Profes Biología. Test para elegir preferencias...
# 3                         Herramientas para docentes
# 4  Imágenes en ciencias sociales y la cultura vis...
#
#                           Conference or journal name  \
# 0                               REVISTA DE EDUCACION
# 1  EURASIA JOURNAL OF MATHEMATICS SCIENCE AND TEC...
# 2                      RESEARCH IN SCIENCE EDUCATION
# 3  The Reading Teacher © 2017 International Liter...
# ...

# %%
authors = data["Authors"].values
authors_list = []
for author in authors:
    [authors_list.append(x.strip()) for x in author.split(';')]
    
authors_list = [x for x in authors_list if x != '']
# display(authors_list)

dfAuthors = pd.DataFrame(authors_list)
dfAuthors.columns = ['Name']
display(dfAuthors.sort_values('Name'))

display(len(dfAuthors.sort_values('Name')))
# Out:
#                                   Name
# 58                            Apol, L.
# 20               Araya Seguel, Claudio
# 33                            Ariga T.
# 51                      Avgerinou M.D.
# 0            Bel Martinez, Juan Carlos
# 9                        Bowen, Tracey
# 24                     Burgess, Joanna
# 22                      Bussert, Kaila
# 6                      Cappello, Marva
# 63  Carpe Pérez, Inmaculada Concepción
# 1                        Cheng, Chu-Yu
# 49                       Chiang, S.-B.
# 48                       Christel M.T.
# 5                        Cook, Kristin
# 13                   Cruz-Benito, Juan
# 54                        Damyanov, I.
# 56                         Domke, L.M.
# 45                             Duić M.
# 46                             Eber, D
# 42                 Esparza-Morales, I.
# 19                      Farías, Miguel
# 7              Gamez-Ceruelo, Virginia
# 12           Garcia-Sanchez, Felicidad
# ...

# %%
resultsAuthors = pd.DataFrame(dfAuthors['Name'].value_counts())
# display(resultsAuthors)
resultsAuthors.reset_index(level=0, inplace=True)
resultsAuthors.columns = ['Name', 'Count']

resultsAuthors.sort_values(['Count', 'Name'], ascending=[False, True], inplace=True)
display(resultsAuthors)
# Out:
#                                   Name  Count
# 21                            Apol, L.      1
# 64               Araya Seguel, Claudio      1
# 25                            Ariga T.      1
# 5                       Avgerinou M.D.      1
# 57           Bel Martinez, Juan Carlos      1
# 16                       Bowen, Tracey      1
# 10                     Burgess, Joanna      1
# 46                      Bussert, Kaila      1
# 42                     Cappello, Marva      1
# 8   Carpe Pérez, Inmaculada Concepción      1
# 29                       Cheng, Chu-Yu      1
# 52                       Chiang, S.-B.      1
# 40                       Christel M.T.      1
# 9                        Cook, Kristin      1
# 47                   Cruz-Benito, Juan      1
# 19                        Damyanov, I.      1
# 55                         Domke, L.M.      1
# 27                             Duić M.      1
# 0                              Eber, D      1
# ...

# %%
p = figure(x_range=resultsAuthors['Name'].tolist(), plot_width=1250, toolbar_location=None, title="Authors Counts")
p.vbar(x=resultsAuthors['Name'].tolist(), top=resultsAuthors['Count'].tolist(), width=0.3)
p.xgrid.grid_line_color = None
p.xaxis.major_label_orientation = math.pi/2

show(p)
# Out:
#   <div class="bk-root" id="22168d16-7e23-4aae-8b52-8fd960317404"></div>

# %%
resultsYears = pd.DataFrame(data['Year'].value_counts())
resultsYears.reset_index(level=0, inplace=True)
resultsYears.columns = ['Year', 'Count']
resultsYears.sort_values(['Year', 'Count'], ascending=[False, False], inplace=True)
display(resultsYears)
# Out:
#     Year  Count
# 2   2018      4
# 0   2017     10
# 3   2016      4
# 1   2015      6
# 5   2014      2
# 6   2013      2
# 7   2010      1
# 8   2009      1
# 4   2008      4
# 9   2006      1
# 10  2003      1
# 11  2002      1
# 12  2000      1
# 13  1989      1

# %%
p = figure(x_range=resultsYears['Year'].astype('str').tolist(), plot_width=600, title="Papers per year")
p.vbar(x=resultsYears['Year'].astype('str').tolist(), top=resultsYears['Count'].astype('int').tolist(), width=0.9)
p.xgrid.grid_line_color = None
p.xaxis.major_label_orientation = math.pi/2

show(p)
# Out:
#   <div class="bk-root" id="0085150c-7146-40ae-93ae-91a311b2aaf8"></div>

# %%
resultsType = pd.DataFrame(data['Type of publication (Journal, Book, Conference proceedings, etc)'].value_counts())
resultsType.reset_index(level=0, inplace=True)
resultsType.columns = ['Type', 'Count']
resultsType.sort_values(['Type', 'Count'], ascending=[False, False], inplace=True)
display(resultsType)
# Out:
#                Type  Count
# 1  Conference paper      8
# 2      Book Chapter      2
# 3              Book      1
# 0           Article     28

# %%
p = figure(x_range=resultsType['Type'].tolist(), title="Publication type")
p.vbar(x=resultsType['Type'].tolist(), top=resultsType['Count'].tolist(), width=0.9)
p.xgrid.grid_line_color = None

show(p)
# Out:
#   <div class="bk-root" id="5ea62e5f-1445-42e8-8fee-838a596ddaab"></div>

# %%
resultsSource = pd.DataFrame(data['Conference or journal name'].value_counts())
resultsSource.reset_index(level=0, inplace=True)
resultsSource.columns = ['Name', 'Count']
resultsSource.sort_values(['Name', 'Count'], ascending=[True, False], inplace=True)
display(resultsSource)
# Out:
#                                                  Name  Count
# 35  11TH INTERNATIONAL CONFERENCE ON INTELLIGENT E...      1
# 3   2008 IEEE INTERNATIONAL PROFESSIONAL COMMUNICA...      1
# 36                  CHILDRENS LITERATURE IN EDUCATION      1
# 20                               COMPUTER GRAPHICS-US      1
# 14              Colombian Applied Linguistics Journal      1
# 25                                       Communicatio      1
# 23  Communications in Computer and Information Sci...      1
# 18  Creating Social Change Through Creativity: Ant...      1
# 31                       E-CIENCIAS DE LA INFORMACION      1
# 11                               ENGLISH IN EDUCATION      1
# 9   EURASIA JOURNAL OF MATHEMATICS SCIENCE AND TEC...      1
# 2                     Educational Media International      1
# 1   Essentials of Teaching and Integrating Visual ...      2
# 29  IEEE International Professional Communication ...      1
# ...

# %%
#p = figure(x_range=resultsSource['Name'].tolist(), plot_width=1250, title="Source (name of the publication)")
#p.vbar(x=resultsSource['Name'].tolist(), top=resultsSource['Count'].tolist(), width=0.3)
#p.xgrid.grid_line_color = None
#p.xaxis.major_label_orientation = math.pi/2

#show(p)

# %%
keywords = data["Keywords"].values
keywords_list = []
for keyword in keywords:
    [keywords_list.append(x.strip()) for x in keyword.split(';')]
    
keywords_list = [x for x in keywords_list if x != '']
# display(keywords_list)

dfKeywords = pd.DataFrame(keywords_list)

dfKeywords = pd.DataFrame(keywords_list)
dfKeywords.columns = ['Keyword']
dfKeywords['Keyword'] = dfKeywords['Keyword'].str.title()
display(dfKeywords.sort_values('Keyword'))
# Out:
#                                                Keyword
# 30                                   1-Early Childhood
# 31                                         2-Childhood
# 32                                 3-Early Adolescence
# 33                                       4-Adolescence
# 100                       Alfabetización Informacional
# 101                              Alfabetización Visual
# 34                               Alfabetización Visual
# 73                               Alfabetización Visual
# 140                              Alfabetización Visual
# 29                                       And Materials
# 26                                       And Materials
# 139                                          Animación
# 64                                       Art Education
# 49                                             Artwork
# 41                                          Assessment
# 60                                    Blended Learning
# ...

# %%
resultsKeywords = pd.DataFrame(dfKeywords['Keyword'].value_counts())
resultsKeywords.reset_index(level=0, inplace=True)
resultsKeywords.columns = ['Keyword', 'Count']

resultsKeywords.sort_values(['Count', 'Keyword'], ascending=[False, True], inplace=True)
display(resultsKeywords)
# Out:
#                                                Keyword  Count
# 0                                      Visual Literacy     12
# 2                                Alfabetización Visual      4
# 3                                     Media Literacies      4
# 1                                 Visual Communication      4
# 7                                        And Materials      2
# 4                                                Image      2
# 8                             Instructional Strategies      2
# 5                                       Interpretation      2
# 9                                              Methods      2
# 6                                         Picturebooks      2
# 57                                   1-Early Childhood      1
# 31                                         2-Childhood      1
# 97                                 3-Early Adolescence      1
# 38                                       4-Adolescence      1
# ...

# %%
p = figure(x_range=resultsKeywords['Keyword'].tolist(), plot_width=1250, title="Keywords Counts")
p.vbar(x=resultsKeywords['Keyword'].tolist(), top=resultsKeywords['Count'].tolist(), width=0.3)
p.xgrid.grid_line_color = None
p.xaxis.major_label_orientation = math.pi/2

show(p)
# Out:
#   <div class="bk-root" id="3f7952b5-9398-4958-8150-426a63b8caef"></div>

# %%
resultsKeywords.shape
# Out:
# (116, 2)

# %%
terms_classification = {}

terms_classification['Visual Literacy']='Education'
terms_classification['Alfabetización Visual']='Education'
terms_classification['Media Literacies']='Education'
terms_classification['Visual Communication']='Communication'
terms_classification['Instructional Strategies']='Education'
terms_classification['Early Childhood']='Education'
terms_classification['Childhood']='Education'
terms_classification['Early Adolescence']='Education'
terms_classification['Adolescence']='Education'
terms_classification['Alfabetización Informacional']='Education'
terms_classification['Art Education']='Education'
terms_classification['Assessment']='Education'
terms_classification['Constructivism']='Education'
terms_classification['Classroom-Based']='Education'
terms_classification['Comunicación']='Communication'
terms_classification['Design Education']='Education'
terms_classification['Educación']='Education'
terms_classification['Education']='Education'
terms_classification['Cms']='ICT'
terms_classification['Digital']='ICT'
terms_classification['Facebook']='ICT'
terms_classification['Flickr']='ICT'
terms_classification['Instagram']='ICT'
terms_classification['Flipped Classroom']='Education'
terms_classification['Blended Learning']='Education'
terms_classification['Web Services']='ICT'
terms_classification['Website Design']='ICT'
terms_classification['Image']='Art & Design'
terms_classification['Picturebooks']='Art & Design'
terms_classification['Animación']='Art & Design'
terms_classification['Artwork']='Art & Design'
terms_classification['Classroom-Based']='Education'
terms_classification['Estudiantes De Mercadotecnia']='Education'
terms_classification['Estudiantes Universitarios']='Education'
terms_classification['Experiential Learning']='Education'
terms_classification['Genre']='Demographics'
terms_classification['Higher Education']='Education'
terms_classification['Intercultural Communication']='Communication'
terms_classification['Language Teaching']='Education'
terms_classification['Learning Background']='Education'
terms_classification['Learning Community']='Education'
terms_classification['Learning Outcomes']='Education'
terms_classification['Learning Strategies < Strategies']='Education'
terms_classification['Learning Visual Literacy']='Education'
terms_classification['New Literacies < Digital']='ICT'
terms_classification['Rubric']='Education'
terms_classification['Rubrics < Assessment']='Education'
terms_classification['Teacher Education']='Education'
terms_classification['Teaching Strategies < Strategies']='Education'
terms_classification['Gestalt Laws']='Psychology'
terms_classification['Nuevas Alfabetizaciones']='Education'
terms_classification['Ilustración']='Art & Design'
terms_classification['Imagery']='Art & Design'
terms_classification['Infographic']='Art & Design'
terms_classification['Highschool Science']='Education'
terms_classification['Representación De La Información']='Information Science'
terms_classification['Visualization']='ICT'
terms_classification['Experiential Learning']='Education'
terms_classification['Information And Communication Technologies < D...']='ICT'
terms_classification['Visual Design']='Art & Design'
terms_classification['Non-Design Student']='Education'
terms_classification['Visual Grammar']='Art & Design'
terms_classification['Visual Language']='Art & Design'
terms_classification['Visual Learning']='Education'
terms_classification['Visual Literacy < Digital']='Education'
terms_classification['Visual Literacy Competence']='Education'
terms_classification['Visual Literacy Representations In Science']='Education'
terms_classification['Visual Critique']='Art & Design'
terms_classification['Visual Media']='ICT'
terms_classification['Visual Methods']='ICT'
terms_classification['Photography']='Art & Design'
terms_classification['Percepción Visual']='Psychology'
terms_classification['Press Photography']='Communication'
terms_classification['Telecollaboration']='Communication'
terms_classification['Journalistic Photograph']='Communication'
terms_classification['Multiuser Virtual Worlds']='ICT'
terms_classification['Multimodality']='ICT'
terms_classification['Multiliteracies']='Education'
terms_classification['Interpretation']='Education'
terms_classification['Cross-Border']='Demographics'
terms_classification['Cognitive Habits']='Psychology'
terms_classification['Visual Aid']='ICT'
terms_classification['Visual Construction']='Art & Design'
terms_classification['Visual Perception']='Psychology'
terms_classification['Visual Representation']='Art & Design'
terms_classification['Visual Thinking']='Psychology'
terms_classification['Libros De Texto']='Education'
terms_classification['E-Business']='Professional Aspects'
terms_classification['Professional Development']='Professional Aspects'
terms_classification['Collaboration']='Communication'
terms_classification['Children’S Literature']='Education'
terms_classification['Documentos Visuales']='Art & Design'
terms_classification['Graphic Novels']='Art & Design'
terms_classification['Textos Multimodales']='ICT'
terms_classification['Comprehension']='Psychology'
terms_classification['Located And Online Learning']='Education'
terms_classification['Intercultural Competence']='Demographics'
terms_classification['Lectura Icónica']='Education'
terms_classification['Selfie']='Communication'
terms_classification['Semiotics']='Communication'
terms_classification['Semantics']='Communication'
terms_classification['Visualizing < Comprehension']='Psychology'
terms_classification['Multimodal Texts']='ICT'
terms_classification['Modelos Sociosemióticos']='Communication'
terms_classification['Evolution Imagery']='Communication'

# %%
terms_clas = pd.DataFrame.from_dict(terms_classification, orient='index')

# %%
display(terms_clas)
# Out:
#                                                                       0
# Visual Literacy                                               Education
# Alfabetización Visual                                         Education
# Media Literacies                                              Education
# Visual Communication                                      Communication
# Instructional Strategies                                      Education
# Early Childhood                                               Education
# Childhood                                                     Education
# Early Adolescence                                             Education
# Adolescence                                                   Education
# Alfabetización Informacional                                  Education
# Art Education                                                 Education
# Assessment                                                    Education
# ...

# %%
resultsTerms = pd.DataFrame(terms_clas[0].value_counts())
resultsTerms.reset_index(level=0, inplace=True)
resultsTerms.columns = ['Application area', 'Count']

resultsTerms.sort_values(['Count', 'Application area'], ascending=[False, True], inplace=True)
display(resultsTerms)
# Out:
#        Application area  Count
# 0             Education     45
# 1                   ICT     17
# 2          Art & Design     16
# 3         Communication     12
# 4            Psychology      7
# 5          Demographics      3
# 6  Professional Aspects      2
# 7   Information Science      1

# %%
p = figure(x_range=resultsTerms['Application area'].tolist(), title="Application area - counts")
p.vbar(x=resultsTerms['Application area'].tolist(), top=resultsTerms['Count'].tolist(), width=0.9)
p.xgrid.grid_line_color = None
p.xaxis.major_label_orientation = math.pi/2

show(p)
# Out:
#   <div class="bk-root" id="b468e06c-947f-4f98-9a3f-46bd1c8f6eff"></div>
